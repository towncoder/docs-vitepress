# %% [markdown]
# ## 个人介绍
#
# [链接](https://zhuanlan.zhihu.com/p/364325502?utm_id=0)
#
# 插入图片试试
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 第二页
#
#
# 这是一段正文测试
#
# 这是一段正文测试

# %%
print("hello world")
# Out:
# hello world
